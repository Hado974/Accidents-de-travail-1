# %%
import pandas as pd

# 1. Chargement des données
file_path = "/home/hado/Projets/Projet_vinci_adt/Data/raw/Injury Severity.xlsx"
df = pd.read_excel(file_path)

# 2. Dimensions du dataset
print(f"Dimensions du dataset (Lignes, Colonnes) : {df.shape}\n")

# 3. Informations générales et types de variables
print("Types de variables et valeurs non nulles :")
df.info()

# 4. Aperçu des données
df.head(10)
# Out:
# Dimensions du dataset (Lignes, Colonnes) : (53550, 24)
#
# Types de variables et valeurs non nulles :
# <class 'pandas.DataFrame'>
# RangeIndex: 53550 entries, 0 to 53549
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   construction     10299 non-null  float64
#  1   state_x          53545 non-null  str
#  2   city_x           53537 non-null  object
#  3   zip_x            53544 non-null  float64
#  4   sic_code         18456 non-null  float64
#  5   date             53550 non-null  datetime64[us]
#  6   fatality         14848 non-null  str
#  7   age_x            53550 non-null  int64
#  8   sex_x            51543 non-null  str
#  9   degree_of_inj_x  53550 non-null  int64
#  10  event_type       53550 non-null  int64
#  11  occ_code         47132 non-null  float64
#  12  event_keyword    53430 non-null  str
#  13  abstract         53549 non-null  object
# ...
